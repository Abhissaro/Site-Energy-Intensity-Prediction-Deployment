# %%
! pip install catboost
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\abhin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\abhin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\abhin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\abhin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\abhin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\abhin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\abhin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\abhin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\abhin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\abhin\anaconda3\lib\site-packages)
# ...

# %%
! pip install category_encoders
# Out:
# ...
#      ---------------------------------------- 72.4/72.4 kB 1.3 MB/s eta 0:00:00
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\abhin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\abhin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\abhin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\abhin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\abhin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\abhin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\abhin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\abhin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\abhin\anaconda3\lib\site-packages)
# ...

# %%
! pip install xgboost
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\abhin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\abhin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\abhin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\abhin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\abhin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\abhin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\abhin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\abhin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\abhin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\abhin\anaconda3\lib\site-packages)
# ...

# %%
import optuna

# %%
import numpy as np
import pandas as pd


import matplotlib.pyplot as plt
import matplotlib.style as style
import seaborn as sns


from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import KNNImputer

from sklearn.feature_selection import SelectFromModel

from sklearn.model_selection import cross_val_score, KFold, train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import mean_absolute_error

from catboost import CatBoostRegressor
from category_encoders import TargetEncoder
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor


import tqdm
import joblib

import shap

pd.set_option('display.max_columns', 70)
plt.rcParams['axes.spines.top']=False
plt.rcParams['axes.spines.right']=False
style.use('ggplot')
sns.set_palette('Set2')

import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('D:/TMLC/Energy Intensity Prediction/Dataset/train.csv')
test = pd.read_csv('D:/TMLC/Energy Intensity Prediction/Dataset/test.csv')

# %%
df_train = train.copy()
df_test = test.copy()

# %%
print(df_train.shape)
print(df_test.shape)
# Out:
# (75757, 64)
# (9705, 63)

# %%
train
# Out:
#        Year_Factor State_Factor building_class  \
# 0                1      State_1     Commercial
# 1                1      State_1     Commercial
# 2                1      State_1     Commercial
# 3                1      State_1     Commercial
# 4                1      State_1     Commercial
# ...            ...          ...            ...
# 75752            6     State_11     Commercial
# 75753            6     State_11    Residential
# 75754            6     State_11     Commercial
# 75755            6     State_11     Commercial
# 75756            6     State_11    Residential
#
#                                    facility_type  floor_area  year_built  \
# 0                   Grocery_store_or_food_market     61242.0      1942.0
# 1      Warehouse_Distribution_or_Shipping_center    274000.0      1955.0
# 2                           Retail_Enclosed_mall    280025.0      1951.0
# 3                      Education_Other_classroom     55325.0      1980.0
# ...

# %%
test
# Out:
#       Year_Factor State_Factor building_class                 facility_type  \
# 0               7      State_1     Commercial  Grocery_store_or_food_market
# 1               7      State_1     Commercial  Grocery_store_or_food_market
# 2               7      State_1     Commercial  Grocery_store_or_food_market
# 3               7      State_1     Commercial  Grocery_store_or_food_market
# 4               7      State_1     Commercial  Grocery_store_or_food_market
# ...           ...          ...            ...                           ...
# 9700            7     State_11    Residential           5plus_Unit_Building
# 9701            7     State_11    Residential           5plus_Unit_Building
# 9702            7     State_11    Residential           5plus_Unit_Building
# 9703            7     State_11    Residential           5plus_Unit_Building
# 9704            7     State_11    Residential           5plus_Unit_Building
#
# ...

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75757 entries, 0 to 75756
# Data columns (total 64 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year_Factor                75757 non-null  int64
#  1   State_Factor               75757 non-null  object
#  2   building_class             75757 non-null  object
#  3   facility_type              75757 non-null  object
#  4   floor_area                 75757 non-null  float64
#  5   year_built                 73920 non-null  float64
#  6   energy_star_rating         49048 non-null  float64
#  7   ELEVATION                  75757 non-null  float64
#  8   january_min_temp           75757 non-null  int64
#  9   january_avg_temp           75757 non-null  float64
#  10  january_max_temp           75757 non-null  int64
#  11  february_min_temp          75757 non-null  int64
#  12  february_avg_temp          75757 non-null  float64
# ...

# %%
print(df_train.duplicated().sum())
print(df_test.duplicated().sum())
# Out:
# 0
# 0

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9705 entries, 0 to 9704
# Data columns (total 63 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year_Factor                9705 non-null   int64
#  1   State_Factor               9705 non-null   object
#  2   building_class             9705 non-null   object
#  3   facility_type              9705 non-null   object
#  4   floor_area                 9705 non-null   float64
#  5   year_built                 9613 non-null   float64
#  6   energy_star_rating         7451 non-null   float64
#  7   ELEVATION                  9705 non-null   float64
#  8   january_min_temp           9705 non-null   int64
#  9   january_avg_temp           9705 non-null   float64
#  10  january_max_temp           9705 non-null   int64
#  11  february_min_temp          9705 non-null   int64
#  12  february_avg_temp          9705 non-null   float64
# ...

# %%
test['site_eui'] = np.nan
test['dataset'] = 'test'
train['dataset'] = 'train'


df_all= pd.concat([train, test], axis=0, ignore_index=True)

# %%
df_all.head(20)
# Out:
#     Year_Factor State_Factor building_class  \
# 0             1      State_1     Commercial
# 1             1      State_1     Commercial
# 2             1      State_1     Commercial
# 3             1      State_1     Commercial
# 4             1      State_1     Commercial
# 5             1      State_1     Commercial
# 6             1      State_1     Commercial
# 7             1      State_1     Commercial
# 8             1      State_1     Commercial
# 9             1      State_1     Commercial
# 10            1      State_1     Commercial
# 11            1      State_1     Commercial
# 12            1      State_1     Commercial
# 13            1      State_1     Commercial
# 14            1      State_1     Commercial
# 15            1      State_1     Commercial
# 16            1      State_1     Commercial
# 17            1      State_1     Commercial
# 18            1      State_1    Residential
# 19            1      State_1     Commercial
#
# ...

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85462 entries, 0 to 85461
# Data columns (total 65 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year_Factor                85462 non-null  int64
#  1   State_Factor               85462 non-null  object
#  2   building_class             85462 non-null  object
#  3   facility_type              85462 non-null  object
#  4   floor_area                 85462 non-null  float64
#  5   year_built                 83533 non-null  float64
#  6   energy_star_rating         56499 non-null  float64
#  7   ELEVATION                  85462 non-null  float64
#  8   january_min_temp           85462 non-null  int64
#  9   january_avg_temp           85462 non-null  float64
#  10  january_max_temp           85462 non-null  int64
#  11  february_min_temp          85462 non-null  int64
#  12  february_avg_temp          85462 non-null  float64
# ...

# %%
df_all.shape
# Out:
# (85462, 65)

# %%
#checking missing values
df_all.isnull().any().sum()
# Out:
# 7

# %%
df_all.isnull().sum().sort_values(ascending = True)
# Out:
# Year_Factor                      0
# id                               0
# september_avg_temp               0
# september_max_temp               0
# october_min_temp                 0
#                              ...
# energy_star_rating           28963
# direction_max_wind_speed     49657
# max_wind_speed               49657
# direction_peak_wind_speed    50386
# days_with_fog                54913
# Length: 65, dtype: int64

# %%
# statistical measures about the data
df_all.describe()
# Out:
#         Year_Factor    floor_area    year_built  energy_star_rating  \
# count  85462.000000  8.546200e+04  83533.000000        56499.000000
# mean       4.666671  1.656694e+05   1953.562616           61.531850
# std        1.617635  2.486965e+05     37.667384           28.595425
# min        1.000000  9.430000e+02      0.000000            0.000000
# 25%        3.000000  6.115500e+04   1927.000000           41.000000
# 50%        5.000000  9.041100e+04   1954.000000           68.000000
# 75%        6.000000  1.671960e+05   1981.000000           85.000000
# max        7.000000  6.385382e+06   2016.000000          100.000000
#
#           ELEVATION  january_min_temp  january_avg_temp  january_max_temp  \
# count  85462.000000      85462.000000      85462.000000      85462.000000
# mean      58.325913         11.669502         34.579333         59.163230
# std      118.276994          9.801683          7.033171          5.425332
# ...

# %%
# checking the distribution of Target Varibale
df_all['site_eui'].value_counts()
# Out:
# 79.781421    36
# 65.819672    36
# 69.210383    35
# 75.094262    35
# 88.557377    33
#              ..
# 10.396353     1
# 75.600517     1
# 66.252720     1
# 65.090565     1
# 29.154684     1
# Name: site_eui, Length: 61080, dtype: int64

# %%
object_columns = df_all.select_dtypes(include=['object']).columns

# %%
object_columns
# Out:
# Index(['State_Factor', 'building_class', 'facility_type', 'dataset'], dtype='object')

# %%
cols = df_all.select_dtypes([np.number]).columns
cols
# Out:
# Index(['Year_Factor', 'floor_area', 'year_built', 'energy_star_rating',
#        'ELEVATION', 'january_min_temp', 'january_avg_temp', 'january_max_temp',
#        'february_min_temp', 'february_avg_temp', 'february_max_temp',
#        'march_min_temp', 'march_avg_temp', 'march_max_temp', 'april_min_temp',
#        'april_avg_temp', 'april_max_temp', 'may_min_temp', 'may_avg_temp',
#        'may_max_temp', 'june_min_temp', 'june_avg_temp', 'june_max_temp',
#        'july_min_temp', 'july_avg_temp', 'july_max_temp', 'august_min_temp',
#        'august_avg_temp', 'august_max_temp', 'september_min_temp',
#        'september_avg_temp', 'september_max_temp', 'october_min_temp',
#        'october_avg_temp', 'october_max_temp', 'november_min_temp',
#        'november_avg_temp', 'november_max_temp', 'december_min_temp',
#        'december_avg_temp', 'december_max_temp', 'cooling_degree_days',
#        'heating_degree_days', 'precipitation_inches', 'snowfall_inches',
# ...

# %%
### Checking Outliers
sns.distplot(df_all['site_eui'])
# Out:
# <AxesSubplot:xlabel='site_eui', ylabel='Density'>

# %% [markdown]
# ### Filling missing values
# ### Catgorical variables with mode and Numerical variables with mean

# %%
df_all[cols] = df_all[cols].fillna(df_all[cols].mean())
df_all[cols]
# Out:
#        Year_Factor  floor_area  year_built  energy_star_rating  ELEVATION  \
# 0                1     61242.0      1942.0                11.0        2.4
# 1                1    274000.0      1955.0                45.0        1.8
# 2                1    280025.0      1951.0                97.0        1.8
# 3                1     55325.0      1980.0                46.0        1.8
# 4                1     66000.0      1985.0               100.0        2.4
# ...            ...         ...         ...                 ...        ...
# 85457            7    305925.0      2013.0                99.0      812.0
# 85458            7     34909.0      1910.0                94.0       26.5
# 85459            7     42393.0      2014.0                94.0      812.0
# 85460            7     25368.0      1992.0                79.0      812.0
# 85461            7     45640.0      1994.0                87.0       26.5
#
#        january_min_temp  january_avg_temp  january_max_temp  \
# ...

# %%
object_columns = ['State_Factor', 'building_class', 'facility_type', 'dataset']
for i in object_columns:
    df_all[i].fillna(df_all[i].mode()[0], inplace=True)
    print(i)
# Out:
# State_Factor
# building_class
# facility_type
# dataset

# %%
df_all.isnull().sum()
# Out:
# Year_Factor       0
# State_Factor      0
# building_class    0
# facility_type     0
# floor_area        0
#                  ..
# max_wind_speed    0
# days_with_fog     0
# site_eui          0
# id                0
# dataset           0
# Length: 65, dtype: int64

# %%
df_all.isnull().any().sum()
# Out:
# 0

# %% [markdown]
# ### Encoding Concept

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
object_columns = ['State_Factor', 'building_class', 'facility_type', 'dataset']

# Encode labels of multiple columns at once

df_all[object_columns] = df_all[object_columns].apply(le.fit_transform)

df_all.head()
# Out:
#    Year_Factor  State_Factor  building_class  facility_type  floor_area  \
# 0            1             0               0             13     61242.0
# 1            1             0               0             55    274000.0
# 2            1             0               0             48    280025.0
# 3            1             0               0              6     55325.0
# 4            1             0               0             56     66000.0
#
#    year_built  energy_star_rating  ELEVATION  january_min_temp  \
# 0      1942.0                11.0        2.4                36
# 1      1955.0                45.0        1.8                36
# 2      1951.0                97.0        1.8                36
# 3      1980.0                46.0        1.8                36
# 4      1985.0               100.0        2.4                36
#
#    january_avg_temp  january_max_temp  february_min_temp  february_avg_temp  \
# ...

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85462 entries, 0 to 85461
# Data columns (total 65 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year_Factor                85462 non-null  int64
#  1   State_Factor               85462 non-null  int64
#  2   building_class             85462 non-null  int64
#  3   facility_type              85462 non-null  int64
#  4   floor_area                 85462 non-null  float64
#  5   year_built                 85462 non-null  float64
#  6   energy_star_rating         85462 non-null  float64
#  7   ELEVATION                  85462 non-null  float64
#  8   january_min_temp           85462 non-null  int64
#  9   january_avg_temp           85462 non-null  float64
#  10  january_max_temp           85462 non-null  int64
#  11  february_min_temp          85462 non-null  int64
#  12  february_avg_temp          85462 non-null  float64
# ...

# %% [markdown]
# ### Building a Model

# %%
df_all.tail(30)
# Out:
#        Year_Factor  State_Factor  building_class  facility_type  floor_area  \
# 85432            7             2               1              1    103554.0
# 85433            7             2               1              1    201656.0
# 85434            7             2               1              1    305537.0
# 85435            7             2               1              1     70850.0
# 85436            7             2               1              1    209583.0
# 85437            7             2               1              1     41510.0
# 85438            7             2               1              1     36600.0
# 85439            7             2               1              1     32870.0
# 85440            7             2               1              1     68669.0
# 85441            7             2               1              1     37581.0
# 85442            7             2               1              1    197368.0
# ...

# %%
train = df_all[df_all['dataset']==1]
test = df_all[df_all['dataset']==0]

train = train.reset_index(drop=True)
test = test.reset_index(drop=True)

test_ids = test['id']
train_ids = train['id']

target = train['site_eui']

train = train.drop(['id', 'dataset', 'site_eui'], axis=1)
test = test.drop(['id', 'dataset', 'site_eui'], axis=1)

# %%
train.head(20)
# Out:
#     Year_Factor  State_Factor  building_class  facility_type  floor_area  \
# 0             1             0               0             13     61242.0
# 1             1             0               0             55    274000.0
# 2             1             0               0             48    280025.0
# 3             1             0               0              6     55325.0
# 4             1             0               0             56     66000.0
# 5             1             0               0             58    119900.0
# 6             1             0               0             56     91367.0
# 7             1             0               0             56     50422.0
# 8             1             0               0             32    122020.0
# 9             1             0               0             32    102612.0
# 10            1             0               0             55     65998.0
# 11            1             0               0             32    100000.0
# ...

# %%
test
# Out:
#       Year_Factor  State_Factor  building_class  facility_type  floor_area  \
# 0               7             0               0             13     28484.0
# 1               7             0               0             13     21906.0
# 2               7             0               0             13     16138.0
# 3               7             0               0             13     97422.0
# 4               7             0               0             13     61242.0
# ...           ...           ...             ...            ...         ...
# 9700            7             2               1              1    305925.0
# 9701            7             2               1              1     34909.0
# 9702            7             2               1              1     42393.0
# 9703            7             2               1              1     25368.0
# 9704            7             2               1              1     45640.0
#
#       year_built  energy_star_rating  ELEVATION  january_min_temp  \
# ...

# %%
train
# Out:
#        Year_Factor  State_Factor  building_class  facility_type  floor_area  \
# 0                1             0               0             13     61242.0
# 1                1             0               0             55    274000.0
# 2                1             0               0             48    280025.0
# 3                1             0               0              6     55325.0
# 4                1             0               0             56     66000.0
# ...            ...           ...             ...            ...         ...
# 75752            6             2               0             32     20410.0
# 75753            6             2               1              1     40489.0
# 75754            6             2               0              2     28072.0
# 75755            6             2               0              2     53575.0
# 75756            6             2               1              0     23888.0
#
# ...

# %%
y_test = pd.read_csv('D:/TMLC/Energy Intensity Prediction/Dataset/Y_test.csv')

X_train = train
X_test = test
y_train = target
y_test = y_test['site_eui']
print('Train: ', X_train.shape)
print('Test:', X_test.shape)
print('Samples: ', y_train.shape)
print('Targets: ', y_test.shape)
# Out:
# Train:  (75757, 62)
# Test: (9705, 62)
# Samples:  (75757,)
# Targets:  (9705,)

# %%
y_test
# Out:
# 0       166.588554
# 1       259.381565
# 2       158.537090
# 3       261.441520
# 4       242.967711
#            ...
# 9700     23.677329
# 9701     20.512284
# 9702     39.285975
# 9703     29.529438
# 9704     15.492899
# Name: site_eui, Length: 9705, dtype: float64

# %% [markdown]
# ### Feature selection

# %%
from sklearn.feature_selection import mutual_info_regression
# determine the mutual information
mutual_info = mutual_info_regression(X_train, y_train)
mutual_info
# Out:
# array([0.20057136, 0.15348904, 0.0403875 , 0.23818532, 0.10170714,
#        0.0677306 , 0.24595926, 0.16430356, 0.24543117, 0.37957895,
#        0.3123305 , 0.37309057, 0.3782162 , 0.33199376, 0.3449395 ,
#        0.38021774, 0.34550293, 0.35780423, 0.37655307, 0.24054924,
#        0.35370585, 0.26759236, 0.30176353, 0.32531439, 0.3785139 ,
#        0.32315824, 0.20167562, 0.37455225, 0.14971255, 0.20667003,
#        0.37810467, 0.33332039, 0.33800106, 0.37423647, 0.28755536,
#        0.28473325, 0.36549753, 0.32676778, 0.36548184, 0.37996458,
#        0.32671927, 0.33907132, 0.37842474, 0.36399339, 0.37693111,
#        0.38010466, 0.37772956, 0.37512117, 0.37396404, 0.38216136,
#        0.37855756, 0.24039878, 0.29969905, 0.27414744, 0.37717755,
#        0.28838978, 0.01360306, 0.        , 0.02989219, 0.02954356,
#        0.02857768, 0.11044373])

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = X_train.columns
mutual_info.sort_values(ascending=False)
# Out:
# avg_temp                     0.382161
# march_avg_temp               0.380218
# heating_degree_days          0.380105
# november_avg_temp            0.379965
# january_avg_temp             0.379579
#                                ...
# direction_max_wind_speed     0.029892
# direction_peak_wind_speed    0.029544
# max_wind_speed               0.028578
# days_above_100F              0.013603
# days_above_110F              0.000000
# Length: 62, dtype: float64

# %%
#let's plot the ordered mutual_info values per feature
mutual_info.sort_values(ascending=False).plot.bar(figsize=(20, 8))
# Out:
# <AxesSubplot:>

# %%
from sklearn.feature_selection import SelectKBest

# %%
#No we Will select the  top 5 important features
sel_five_cols = SelectKBest(mutual_info_regression, k=5)
sel_five_cols.fit(X_train, y_train)
X_train.columns[sel_five_cols.get_support()]
# Out:
# Index(['january_avg_temp', 'november_avg_temp', 'december_avg_temp',
#        'heating_degree_days', 'avg_temp'],
#       dtype='object')

# %%
X_train.shape
# Out:
# (75757, 62)

# %%
X_train_new = sel_five_cols.transform(X_train)
X_test_new =  sel_five_cols.transform(X_test)

# %%
X_train_new.shape
# Out:
# (75757, 5)

# %%
xgb = XGBRegressor(n_estimators=500, reg_alpha=0.01, n_jobs=-1)
xgb.fit(X_train_new, y_train)
y_pred = xgb.predict(X_test_new)

# %%
print(" Training data scores\n","--"*10)
print(" RMSE:", np.sqrt(mean_squared_error(y_test,y_pred)))
print(" MAE:", mean_absolute_error(y_test,y_pred))
print(" MSE:", mean_squared_error(y_test,y_pred))
print(" R2:", r2_score(y_test,y_pred))
# Out:
#  Training data scores
#  --------------------
#  RMSE: 64.25991365283973
#  MAE: 40.45224115327223
#  MSE: 4129.336502670417
#  R2: -0.14206438183271186

# %%
rf = RandomForestRegressor(random_state=1, criterion='mse', max_depth = 15, min_samples_split= 2)
rf.fit(X_train_new, y_train)
y_pred = rf.predict(X_test_new)

# %%
print(" Training data scores\n","--"*10)
print(" RMSE:", np.sqrt(mean_squared_error(y_test,y_pred)))
print(" MAE:", mean_absolute_error(y_test,y_pred))
print(" MSE:", mean_squared_error(y_test,y_pred))
print(" R2:", r2_score(y_test,y_pred))
# Out:
#  Training data scores
#  --------------------
#  RMSE: 62.22484037269603
#  MAE: 38.64830730397032
#  MSE: 3871.930759407502
#  R2: -0.0708728161006289

# %%
model =  RandomForestRegressor()

# %%
model.fit(X_train_new, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred =model.predict(X_test_new)

# %%
y_pred
# Out:
# array([33.71686518, 33.71686518, 33.71686518, ..., 85.98683656,
#        85.98683656, 85.98683656])

# %% [markdown]
# ### Final Evaluation (Random Forest)

# %%
y_hat_tuned = model.predict(X_test_new)

plt.figure(figsize = (7,5))
sns.distplot(y_test - y_hat_tuned)
plt.title("Error Rate Distribution");
plt.ylabel("error")
plt.xlabel("iteration")
# Out:
# Text(0.5, 0, 'iteration')

# %% [markdown]
# ### Saving Models

# %%
import pickle 
pickle_out = open("model.pkl", mode = "wb") 
pickle.dump(model, pickle_out) 
pickle_out.close()
